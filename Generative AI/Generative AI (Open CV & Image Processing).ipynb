# %% [markdown]
# ## Install library

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %% [markdown]
# ## Read the image

# %%
img = cv2.imread(r'C:\Users\LENOVO\Downloads\wallpaper.jpg')

# %%
img
# Out:
# array([[[12, 11,  7],
#         [12, 11,  7],
#         [11, 10,  6],
#         ...,
#         [ 4,  8,  3],
#         [ 4,  8,  3],
#         [ 4,  8,  3]],
#
#        [[12, 11,  7],
#         [11, 10,  6],
#         [11, 10,  6],
#         ...,
#         [ 4,  8,  3],
#         [ 4,  8,  3],
#         [ 4,  8,  3]],
#
#        [[11, 10,  6],
#         [11, 10,  6],
#         [11, 10,  6],
#         ...,
#         [ 4,  8,  3],
#         [ 4,  8,  3],
#         [ 4,  8,  3]],
#
#        ...,
#
#        [[23, 25, 26],
#         [25, 27, 28],
#         [28, 30, 31],
#         ...,
#         [12, 10, 10],
#         [12, 10, 10],
#         [12, 10, 10]],
#
#        [[22, 24, 25],
#         [24, 26, 27],
#         [27, 29, 30],
#         ...,
#         [12, 10, 10],
#         [12, 10, 10],
#         [12, 10, 10]],
#
#        [[22, 24, 25],
#         [24, 26, 27],
#         [27, 29, 30],
#         ...,
#         [12, 10, 10],
#         [12, 10, 10],
#         [12, 10, 10]]], dtype=uint8)

# %%
type(img)   # type of img
# Out:
# numpy.ndarray

# %%
img.shape  # shape of img
# Out:
# (667, 1000, 3)

# %%
# visualize the image

plt.imshow(img)

# %% [markdown]
# ## Original image

# %%
# Change the color of the image from bgr to rgb (in opencv we get image in "bgr" format) 
# To get the original image we change it to rgb

fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
fix_img
# Out:
# array([[[ 7, 11, 12],
#         [ 7, 11, 12],
#         [ 6, 10, 11],
#         ...,
#         [ 3,  8,  4],
#         [ 3,  8,  4],
#         [ 3,  8,  4]],
#
#        [[ 7, 11, 12],
#         [ 6, 10, 11],
#         [ 6, 10, 11],
#         ...,
#         [ 3,  8,  4],
#         [ 3,  8,  4],
#         [ 3,  8,  4]],
#
#        [[ 6, 10, 11],
#         [ 6, 10, 11],
#         [ 6, 10, 11],
#         ...,
#         [ 3,  8,  4],
#         [ 3,  8,  4],
#         [ 3,  8,  4]],
#
#        ...,
#
#        [[26, 25, 23],
#         [28, 27, 25],
#         [31, 30, 28],
#         ...,
#         [10, 10, 12],
#         [10, 10, 12],
#         [10, 10, 12]],
#
#        [[25, 24, 22],
#         [27, 26, 24],
#         [30, 29, 27],
#         ...,
#         [10, 10, 12],
#         [10, 10, 12],
#         [10, 10, 12]],
#
#        [[25, 24, 22],
#         [27, 26, 24],
#         [30, 29, 27],
#         ...,
#         [10, 10, 12],
#         [10, 10, 12],
#         [10, 10, 12]]], dtype=uint8)

# %%
plt.imshow(fix_img)  # visualize the image

# %% [markdown]
# ## Gray-Scale image

# %%
img_gray = cv2.imread(r'C:\Users\LENOVO\Downloads\wallpaper.jpg',  cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (667, 1000)

# %%
img_gray
# Out:
# array([[10, 10,  9, ...,  6,  6,  6],
#        [10,  9,  9, ...,  6,  6,  6],
#        [ 9,  9,  9, ...,  6,  6,  6],
#        ...,
#        [25, 27, 30, ..., 10, 10, 10],
#        [24, 26, 29, ..., 10, 10, 10],
#        [24, 26, 29, ..., 10, 10, 10]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)

# %%
# Using cmap = 'gray' we get black and white image

plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
plt.imshow(img_gray, cmap='Accent')

# %%
fix_img.shape
# Out:
# (667, 1000, 3)

# %% [markdown]
# ## Resize the image

# %%
fix_img2 = cv2.resize(fix_img , (333,500))

# %%
fix_img2.shape
# Out:
# (500, 333, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img , (0,0), fix_img, w_ratio , h_ratio)

# %%
fix_img_2
# Out:
# array([[[ 7, 11, 12],
#         [ 6, 10, 11],
#         [ 5, 10, 11],
#         ...,
#         [ 3,  8,  4],
#         [ 3,  8,  4],
#         [ 3,  8,  4]],
#
#        [[ 6, 10, 11],
#         [ 6, 10, 11],
#         [ 5, 10, 11],
#         ...,
#         [ 4,  9,  5],
#         [ 3,  8,  4],
#         [ 3,  8,  5]],
#
#        [[ 5,  9, 10],
#         [ 6, 10, 11],
#         [ 6, 11, 11],
#         ...,
#         [ 4,  9,  5],
#         [ 3,  8,  6],
#         [ 3,  7,  6]],
#
#        ...,
#
#        [[29, 25, 24],
#         [32, 30, 28],
#         [43, 42, 38],
#         ...,
#         [10, 10, 12],
#         [10, 10, 12],
#         [10, 10, 12]],
#
#        [[27, 26, 24],
#         [33, 32, 30],
#         [40, 39, 37],
#         ...,
#         [10, 10, 12],
#         [10, 10, 12],
#         [10, 10, 12]],
#
#        [[26, 25, 23],
#         [32, 30, 28],
#         [37, 36, 34],
#         ...,
#         [10, 10, 12],
#         [10, 10, 12],
#         [10, 10, 12]]], dtype=uint8)

# %%
plt.imshow(fix_img_2)

# %% [markdown]
# ### Flip the image

# %%
img3 = cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
img4 = cv2.flip(fix_img_2,1)
plt.imshow(img3)

# %% [markdown]
# ### Save the image

# %%
cv2.imwrite('Generative AI Image.jpg',img3)
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\LENOVO\\Desktop\\Naresh IT\\Generative AI'
